# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import numpy as np

# %%
# Load a single split of the dataset
dataset = load_dataset('nlphuji/flickr30k', split='test')

# 1. Prepare your caption data
# Assuming each item's 'caption' field is a list of captions
all_captions = [caption for item in dataset for caption in item['caption']]

# Write captions to a file, one caption per line
with open('captions.txt', 'w', encoding='utf-8') as f:
    for caption in all_captions:
        f.write(caption + '\n')
# Out:
# Repo card metadata block was not found. Setting CardData to empty.

# %%
#2.  Train a SentencePiece model on the captions

spm.SentencePieceTrainer.train(input='captions.txt', model_prefix='flickr_captions', vocab_size=8000, model_type='bpe')

#  two files: flickr_captions.model and flickr_captions.vocab, which are your trained SentencePiece model and its vocabulary
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: captions.txt
#   input_format:
#   model_prefix: flickr_captions
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: captions.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 155070 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=9955402
# trainer_interface.cc(550) LOG(INFO) Done: 99.9528% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=53
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999528
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 155070 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 155070
# trainer_interface.cc(609) LOG(INFO) Done! 34068
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=302509 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64188 size=20 all=1910 active=1711 piece=is
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37879 size=40 all=2731 active=2532 piece=ck
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22143 size=60 all=3589 active=3390 piece=ear
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16879 size=80 all=4276 active=4077 piece=all
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13609 size=100 all=4866 active=4667 piece=▁sit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13516 min_freq=527
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11678 size=120 all=5326 active=1454 piece=ot
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9966 size=140 all=5918 active=2046 piece=us
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7843 size=160 all=6513 active=2641 piece=roup
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6567 size=180 all=6977 active=3105 piece=▁ta
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5697 size=200 all=7682 active=3810 piece=▁som
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5685 min_freq=569
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5145 size=220 all=8105 active=1419 piece=▁green
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4720 size=240 all=8468 active=1782 piece=ther
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4416 size=260 all=8782 active=2096 piece=erson
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3985 size=280 all=9276 active=2590 piece=che
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3621 size=300 all=9623 active=2937 piece=▁into
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3612 min_freq=517
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3251 size=320 all=9891 active=1268 piece=▁running
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3039 size=340 all=10382 active=1759 piece=ist
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2786 size=360 all=10685 active=2062 piece=ture
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2583 size=380 all=11101 active=2478 piece=ching
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2392 size=400 all=11378 active=2755 piece=▁tal
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2380 min_freq=454
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2259 size=420 all=11891 active=1511 piece=do
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2130 size=440 all=12184 active=1804 piece=▁dan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2008 size=460 all=12407 active=2027 piece=les
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1888 size=480 all=12692 active=2312 piece=▁uniform
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1804 size=500 all=13043 active=2663 piece=▁ad
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1798 min_freq=400
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1706 size=520 all=13360 active=1304 piece=▁br
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1619 size=540 all=13635 active=1579 piece=▁climb
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1529 size=560 all=13890 active=1834 piece=uth
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1470 size=580 all=14070 active=2014 piece=stru
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1421 size=600 all=14367 active=2311 piece=▁sweat
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1416 min_freq=352
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1353 size=620 all=14568 active=1195 piece=▁ve
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1322 size=640 all=14887 active=1514 piece=ents
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1260 size=660 all=15025 active=1652 piece=▁L
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1187 size=680 all=15201 active=1828 piece=row
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1123 size=700 all=15537 active=2164 piece=▁prep
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1121 min_freq=311
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1069 size=720 all=15809 active=1267 piece=▁construction
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1022 size=740 all=15977 active=1435 piece=▁rides
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=991 size=760 all=16166 active=1624 piece=▁ocean
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=950 size=780 all=16334 active=1792 piece=▁restaur
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=922 size=800 all=16410 active=1868 piece=strum
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=922 min_freq=278
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=876 size=820 all=16598 active=1185 piece=less
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=820 size=840 all=16828 active=1415 piece=ron
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=796 size=860 all=17030 active=1617 piece=▁cow
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=764 size=880 all=17301 active=1888 piece=▁kitchen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=742 size=900 all=17502 active=2089 piece=▁af
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=740 min_freq=252
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=713 size=920 all=17648 active=1139 piece=ris
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=684 size=940 all=17929 active=1420 piece=▁hard
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=659 size=960 all=18122 active=1613 piece=▁gather
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=639 size=980 all=18195 active=1686 piece=▁pra
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=620 size=1000 all=18447 active=1938 piece=room
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=620 min_freq=229
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=599 size=1020 all=18565 active=1098 piece=▁2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=584 size=1040 all=18768 active=1301 piece=▁pole
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=569 size=1060 all=18980 active=1513 piece=▁crowded
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=558 size=1080 all=19099 active=1632 piece=▁class
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=542 size=1100 all=19265 active=1798 piece=▁fishing
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=540 min_freq=207
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=528 size=1120 all=19417 active=1153 piece=ening
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=508 size=1140 all=19482 active=1218 piece=▁forest
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=494 size=1160 all=19566 active=1302 piece=▁check
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=484 size=1180 all=19703 active=1439 piece=▁blow
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=471 size=1200 all=19874 active=1610 piece=▁cup
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=471 min_freq=189
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=459 size=1220 all=20032 active=1154 piece=▁cooking
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=448 size=1240 all=20179 active=1301 piece=▁works
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=436 size=1260 all=20272 active=1394 piece=▁does
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=422 size=1280 all=20401 active=1523 piece=▁where
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=413 size=1300 all=20588 active=1710 piece=▁instrument
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=412 min_freq=170
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=404 size=1320 all=20716 active=1156 piece=▁bucket
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=394 size=1340 all=20824 active=1264 piece=du
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=386 size=1360 all=20934 active=1374 piece=cl
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=379 size=1380 all=21046 active=1486 piece=▁cream
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=367 size=1400 all=21133 active=1573 piece=alle
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=367 min_freq=155
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=360 size=1420 all=21329 active=1231 piece=looking
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=354 size=1440 all=21486 active=1388 piece=eling
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=344 size=1460 all=21548 active=1450 piece=▁mil
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=336 size=1480 all=21655 active=1557 piece=ou
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=330 size=1500 all=21738 active=1640 piece=▁counter
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=329 min_freq=138
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=323 size=1520 all=21821 active=1167 piece=▁qu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=315 size=1540 all=21966 active=1312 piece=vert
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=310 size=1560 all=22108 active=1454 piece=▁fol
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=305 size=1580 all=22206 active=1552 piece=▁conversation
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=299 size=1600 all=22297 active=1643 piece=▁skateboarding
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=298 min_freq=128
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=292 size=1620 all=22434 active=1252 piece=▁legs
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=285 size=1640 all=22571 active=1389 piece=alm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=278 size=1660 all=22624 active=1442 piece=▁outfits
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=270 size=1680 all=22707 active=1525 piece=icip
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=265 size=1700 all=22797 active=1615 piece=cord
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=265 min_freq=117
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=260 size=1720 all=22894 active=1229 piece=alf
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=256 size=1740 all=23002 active=1337 piece=▁sunset
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=252 size=1760 all=23083 active=1418 piece=tor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=248 size=1780 all=23175 active=1510 piece=▁Construction
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=59 min_freq=33
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=3920 all=28631 active=1420 piece=gu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=3940 all=28714 active=1503 piece=▁midst
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=3960 all=28714 active=1503 piece=▁handrail
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=3980 all=28776 active=1565 piece=▁link
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=4000 all=28775 active=1564 piece=▁industrial
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=57 min_freq=32
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=4020 all=28816 active=1480 piece=▁McDon
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=4040 all=28837 active=1501 piece=hop
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=4060 all=28903 active=1567 piece=▁text
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=4080 all=28915 active=1579 piece=▁lacrosse
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=4100 all=28922 active=1586 piece=▁scaffold
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=54 min_freq=31
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=4120 all=28960 active=1484 piece=▁give
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=4140 all=28964 active=1488 piece=▁lounging
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=4160 all=29016 active=1540 piece=▁fed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=4180 all=29029 active=1553 piece=▁highway
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=4200 all=29072 active=1596 piece=▁late
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=51 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=4220 all=29074 active=1455 piece=▁briefcase
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=4240 all=29123 active=1504 piece=▁find
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=4260 all=29134 active=1515 piece=▁homemade
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=4280 all=29208 active=1589 piece=rant
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=4300 all=29245 active=1626 piece=▁autumn
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=49 min_freq=28
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=4320 all=29235 active=1452 piece=▁containing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=4340 all=29288 active=1505 piece=▁chefs
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=4360 all=29285 active=1502 piece=bby
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=4380 all=29358 active=1575 piece=▁leas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=4400 all=29363 active=1580 piece=▁columns
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=47 min_freq=27
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=4420 all=29348 active=1454 piece=ama
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=4440 all=29440 active=1546 piece=▁kimon
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=4460 all=29437 active=1543 piece=▁tackling
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=4480 all=29505 active=1611 piece=▁menu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=4500 all=29510 active=1616 piece=▁oranges
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=45 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=4520 all=29532 active=1497 piece=▁Mon
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=4540 all=29563 active=1528 piece=▁strugg
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=4560 all=29553 active=1518 piece=▁auditorium
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=4580 all=29615 active=1580 piece=▁shru
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=4600 all=29634 active=1599 piece=▁casting
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=43 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=4620 all=29647 active=1495 piece=iday
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=4640 all=29706 active=1554 piece=▁tags
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=4660 all=29725 active=1573 piece=▁upward
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=4680 all=29709 active=1557 piece=▁champagne
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=4700 all=29769 active=1617 piece=apped
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=41 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=4720 all=29804 active=1521 piece=▁Roller
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=4740 all=29790 active=1507 piece=▁bystanders
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=4760 all=29843 active=1560 piece=▁sen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=4780 all=29853 active=1570 piece=▁sailor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=4800 all=29845 active=1562 piece=ils
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=39 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=4820 all=29878 active=1515 piece=▁tread
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=4840 all=29866 active=1503 piece=▁stirring
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=4860 all=29897 active=1534 piece=lent
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=4880 all=29936 active=1573 piece=▁apart
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=4900 all=29928 active=1565 piece=▁McDonald
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=38 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=4920 all=29951 active=1520 piece=haps
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=4940 all=29983 active=1552 piece=▁when
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=4960 all=29987 active=1556 piece=▁garment
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=4980 all=30027 active=1596 piece=▁Per
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=5000 all=30045 active=1614 piece=▁acting
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=36 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=5020 all=30026 active=1484 piece=▁climbers
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=5040 all=30027 active=1485 piece=rid
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=5060 all=30111 active=1569 piece=▁With
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=5080 all=30123 active=1581 piece=▁exiting
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=5100 all=30105 active=1563 piece=▁medieval
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=35 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=5120 all=30138 active=1539 piece=vices
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=5140 all=30151 active=1552 piece=▁split
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=5160 all=30146 active=1547 piece=▁propped
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=5180 all=30132 active=1533 piece=▁mountaintop
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=5200 all=30210 active=1611 piece=▁bust
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=33 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=5220 all=30226 active=1522 piece=▁early
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=5240 all=30231 active=1527 piece=▁caution
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=5260 all=30215 active=1511 piece=▁cluttered
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=5280 all=30270 active=1566 piece=▁fac
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=5300 all=30302 active=1598 piece=▁test
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=32 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=5320 all=30328 active=1542 piece=▁surge
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=5340 all=30325 active=1539 piece=▁Spanish
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=5360 all=30309 active=1523 piece=▁fireplace
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=5380 all=30351 active=1565 piece=toon
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=5400 all=30391 active=1605 piece=▁buggy
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=31 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=5420 all=30383 active=1512 piece=▁floors
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=5440 all=30376 active=1505 piece=▁ordering
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=5460 all=30464 active=1593 piece=inas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=5480 all=30505 active=1634 piece=▁laun
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=5500 all=30519 active=1648 piece=▁dried
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=30 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=5520 all=30511 active=1518 piece=▁divers
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=5540 all=30505 active=1512 piece=chronized
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=5560 all=30489 active=1496 piece=dot
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=5580 all=30530 active=1537 piece=▁hung
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=5600 all=30541 active=1548 piece=▁braids
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=29 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=5620 all=30529 active=1516 piece=▁Scottish
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5640 all=30530 active=1517 piece=oma
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5660 all=30580 active=1567 piece=andom
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5680 all=30608 active=1595 piece=▁spin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5700 all=30612 active=1599 piece=issance
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=28 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5720 all=30607 active=1524 piece=▁gliding
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=5740 all=30592 active=1509 piece=▁parasailing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=5760 all=30669 active=1586 piece=▁All
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=5780 all=30706 active=1623 piece=▁Grand
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=5800 all=30707 active=1624 piece=▁picker
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=27 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=5820 all=30688 active=1517 piece=▁offering
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5840 all=30672 active=1501 piece=yo
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5860 all=30745 active=1574 piece=▁lin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5880 all=30771 active=1600 piece=▁swan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5900 all=30768 active=1597 piece=▁campus
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=26 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5920 all=30766 active=1537 piece=▁screens
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=5940 all=30752 active=1523 piece=▁xylophone
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=5960 all=30791 active=1562 piece=▁Ob
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=5980 all=30859 active=1630 piece=▁ted
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=6000 all=30889 active=1660 piece=▁chews
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=25 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=6020 all=30886 active=1542 piece=▁helped
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=6040 all=30877 active=1533 piece=▁technic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=6060 all=30868 active=1524 piece=▁everywhere
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=6080 all=30905 active=1561 piece=allic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=6100 all=30925 active=1581 piece=ashing
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=24 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=6120 all=30930 active=1547 piece=▁Orange
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=6140 all=30916 active=1533 piece=▁leopard
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=6160 all=30898 active=1515 piece=▁favorite
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=6180 all=30890 active=1507 piece=inn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=6200 all=30983 active=1600 piece=▁vio
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=23 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=6220 all=31002 active=1565 piece=semble
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=6240 all=31001 active=1564 piece=ongeBob
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=6260 all=30991 active=1554 piece=▁season
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=6280 all=30984 active=1547 piece=▁weights
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=6300 all=30967 active=1530 piece=▁adolescent
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=23 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=6320 all=30991 active=1573 piece=▁ga
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=6340 all=31049 active=1631 piece=▁zoo
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=6360 all=31070 active=1652 piece=▁Amish
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=6380 all=31068 active=1650 piece=undreds
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=6400 all=31056 active=1638 piece=▁message
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=22 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=6420 all=31040 active=1537 piece=▁obscured
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=6440 all=31021 active=1518 piece=▁windbreaker
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=6460 all=31100 active=1597 piece=llip
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=6480 all=31157 active=1654 piece=▁bong
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=6500 all=31171 active=1668 piece=▁casts
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=6520 all=31175 active=1563 piece=▁Groups
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=6540 all=31167 active=1555 piece=▁topped
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=6560 all=31155 active=1543 piece=▁crutches
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=6580 all=31140 active=1528 piece=▁elementary
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=6600 all=31205 active=1593 piece=oose
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=6620 all=31252 active=1598 piece=▁purs
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=6640 all=31258 active=1604 piece=▁lives
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=6660 all=31251 active=1597 piece=▁beyond
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=6680 all=31238 active=1584 piece=▁tagged
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=6700 all=31227 active=1573 piece=▁tightly
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=6720 all=31207 active=1542 piece=▁swimwear
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=6740 all=31192 active=1527 piece=▁electronics
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6760 all=31237 active=1572 piece=velo
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6780 all=31276 active=1611 piece=shore
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6800 all=31286 active=1621 piece=itting
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6820 all=31285 active=1560 piece=▁meats
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6840 all=31288 active=1563 piece=▁Crowds
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6860 all=31278 active=1553 piece=▁kiddie
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6880 all=31266 active=1541 piece=▁awkward
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6900 all=31251 active=1526 piece=▁assorted
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6920 all=31234 active=1546 piece=▁gymnastic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=6940 all=31214 active=1526 piece=▁Professional
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=6960 all=31271 active=1583 piece=eyed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=6980 all=31299 active=1611 piece=climb
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=7000 all=31320 active=1632 piece=▁grip
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=7020 all=31332 active=1578 piece=headed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=7040 all=31340 active=1586 piece=▁limbs
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=7060 all=31346 active=1592 piece=▁bounds
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=7080 all=31338 active=1584 piece=▁slowly
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=7100 all=31326 active=1572 piece=▁monster
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=7120 all=31313 active=1554 piece=▁ascending
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=7140 all=31293 active=1534 piece=▁handkerchief
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7160 all=31364 active=1605 piece=otch
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7180 all=31383 active=1624 piece=riage
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7200 all=31388 active=1629 piece=▁turb
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7220 all=31406 active=1584 piece=▁proje
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7240 all=31399 active=1577 piece=▁croche
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7260 all=31398 active=1576 piece=▁Outdoor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7280 all=31385 active=1563 piece=▁shields
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7300 all=31370 active=1548 piece=▁shouting
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=7320 all=31350 active=1549 piece=▁stoplight
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7340 all=31344 active=1543 piece=ij
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7360 all=31402 active=1601 piece=omet
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7380 all=31452 active=1651 piece=▁sed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7400 all=31488 active=1687 piece=▁iced
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=16 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7420 all=31499 active=1586 piece=▁Skier
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7440 all=31493 active=1580 piece=▁visit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7460 all=31482 active=1569 piece=▁Concert
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7480 all=31469 active=1556 piece=▁parasol
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7500 all=31456 active=1543 piece=▁manipula
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=16 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7520 all=31442 active=1556 piece=▁squinting
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=7540 all=31422 active=1536 piece=▁instructions
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7560 all=31509 active=1623 piece=erry
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7580 all=31566 active=1680 piece=▁eff
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7600 all=31594 active=1708 piece=▁Mart
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=15 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7620 all=31604 active=1586 piece=▁twin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7640 all=31612 active=1594 piece=▁bulls
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7660 all=31612 active=1594 piece=reading
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7680 all=31606 active=1588 piece=▁onesie
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7700 all=31590 active=1572 piece=▁begging
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=15 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7720 all=31580 active=1570 piece=▁sandwic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7740 all=31565 active=1555 piece=▁pedaling
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=7760 all=31552 active=1542 piece=▁conditions
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7780 all=31561 active=1551 piece=wer
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7800 all=31618 active=1608 piece=▁Sup
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=14 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7820 all=31641 active=1602 piece=onies
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7840 all=31652 active=1613 piece=▁size
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7860 all=31663 active=1624 piece=▁clerk
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7880 all=31654 active=1615 piece=▁sushi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7900 all=31648 active=1609 piece=▁dreads
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=14 min_freq=9
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7920 all=31636 active=1571 piece=▁spikes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=7940 all=31619 active=1554 piece=▁machete
# trainer_interface.cc(687) LOG(INFO) Saving model: flickr_captions.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: flickr_captions.vocab

# %%
class Flickr30kDataset(Dataset):
    def __init__(self, split, tokenizer_model, patch_size=16):
       
        self.dataset = load_dataset("nlphuji/flickr30k")[split]
        
        # Load the SentencePiece tokenizer
        self.sp = spm.SentencePieceProcessor(model_file='flickr_captions.model')
        
        # Define the special tokens
        self.sos_token = self.sp.piece_to_id('<s>')  # Start of sentence token
        self.eos_token = self.sp.piece_to_id('</s>')  # End of sentence token
        
        self.patch_size = patch_size

        # Flatten the dataset: create an entry for each (image, caption) pair
        self.items = [(item['image'], caption) for item in dataset for caption in item['caption']]
        

        # Define image transformations
        self.transform = transforms.Compose([
            transforms.Resize((256, 256)),  # Resize images to a fixed size
            transforms.ToTensor(),  # Convert images to tensor
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize images
        ])
        
        
    def __len__(self):
        return len(self.items)

    
    def __getitem__(self, idx):

         #Access the flattened item
        image_path, caption = self.items[idx]
        
        # Load and process the image
        image = Image.open(image_path).convert('RGB')
        image = self.transform(image)
        
        # Split the image into patches and unroll
        patches = self.image_to_patches(image)

        # Tokenize the selected caption
        tokenized_caption = self.sp.encode(caption, out_type=int)
        caption_input = [self.sp.bos_id()] + tokenized_caption
        caption_label = tokenized_caption + [self.sp.eos_id()]
        
        # Return the processed data
        return image, torch.tensor(caption_input), torch.tensor(caption_label)
        
    
    def image_to_patches(self, image):
        """
        Split the image into fixed-size patches and unroll each patch into a one-dimensional vector.
        """
        C, H, W = image.shape
        patch_size = self.patch_size
        patches = image.unfold(1, patch_size, patch_size).unfold(2, patch_size, patch_size)
        patches = patches.contiguous().view(C, -1, patch_size*patch_size)
        patches = patches.permute(1, 0, 2).reshape(-1, C*patch_size*patch_size)
        return patches

# %%
#image, caption_inputs, caption_labels = dataset[0]  # Get the first item

# %%
dataset_split = 'test'  
patch_size = 16  

flickr_dataset = Flickr30kDataset(dataset_split, tokenizer_model, patch_size=patch_size)
dataloader = DataLoader(flickr_dataset, batch_size=32, shuffle=True)
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
